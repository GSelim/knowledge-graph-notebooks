# %%
import rdflib
from rdflib.extras.external_graph_libs import rdflib_to_networkx_multidigraph
import networkx as nx
import matplotlib.pyplot as plt
import re
from random import sample
import graphdb
import pandas as pd
import numpy as np

from SPARQLWrapper import SPARQLWrapper, JSON

# %%
sparql = SPARQLWrapper(
    "http://LAPTOP-CS19OKIS:7200/repositories/tach1"
)
sparql.setReturnFormat(JSON)

queryString4="""
SELECT ?o ?p ?s WHERE{
    # ?o ?p ?s
    }

"""

# %%
sparql.setQuery(queryString4)

test=[]
dataf={}
try:
    ret = sparql.queryAndConvert()
    dataf['o']=[]
    dataf['p']=[]
    dataf['s']=[]
    for r in ret["results"]["bindings"]:
        #print(r)
        #print(r["O"]["value"])
        dataf['o'].append(r['o']["value"])
        dataf['p'].append(r['p']["value"])
        dataf['s'].append(r['s']["value"])
        if r['o']["value"] not in test:
            test.append(r['o']["value"])
        if r["s"]["value"] not in test:    
            test.append(r["s"]["value"])
    

        
except Exception as e:
    print(e)


df=pd.DataFrame(dataf)

# %%
def cleanDataFrame(df):

    
    dataset=df
    
    listeu=dataset["p"]
    dataset=dataset[-dataset["o"].isin(listeu)]
    
    dataset=dataset[-dataset["o"].str.match(".*www.w3.org.*")]
    

    
    pat = r'.*\/(.)'
    dataset["s"]= dataset["s"].str.replace(pat,r'\1',regex=True)
    dataset["o"]= dataset["o"].str.replace(pat,r'\1',regex=True)
    
    lab=dataset[dataset["p"].isin(["http://www.w3.org/2000/01/rdf-schema#label","http://www.w3.org/2006/vcard/ns#fn"])]
    labels=lab["s"].tolist()
    urls=lab["o"].tolist()
    
    dataset=pd.concat([lab, dataset]).drop_duplicates(keep=False)

    dataset=dataset.replace(urls,labels)
    
    dataset["o"]=dataset["o"].str.replace(".*#(.)",r'\1',regex=True)
    dataset["s"]=dataset["s"].str.replace(".*#(.)",r'\1',regex=True)

    return dataset

momo=cleanDataFrame(df)
momo
# Out:
#                            o                                                p  \
# 33                       Aín  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 37                   BENIALI  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 41      Comunidad Valenciana  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 43                Plana_Baja  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 45    provincia de Castellón  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ...                      ...                                              ...
# 7561               LA BOLERA         http://www.w3.org/2006/vcard/ns#hasEmail
# 7562            CRYSTAL-PARK         http://www.w3.org/2006/vcard/ns#hasEmail
# 7563          NOU CASABLANCA         http://www.w3.org/2006/vcard/ns#hasEmail
# 7564        RH VINAROS PLAYA         http://www.w3.org/2006/vcard/ns#hasEmail
# 7565     HOSPEDERIA LA BALMA         http://www.w3.org/2006/vcard/ns#hasEmail
#
#                                          s
# 33                               Municipio
# 37                                   hotel
# 41                       ComunidadAutonoma
# 43                                 Comarca
# 45                               Provincia
# ...                                    ...
# 7561  hotelrestaurantelabolera@hotmail.com
# 7562            hotelcrystalpark@gmail.com
# 7563               noucasablanca@gmail.com
# 7564            vinarosplaya@hotelesrh.com
# 7565                  bealabalma@gmail.com
#
# [6975 rows x 3 columns]

# %%
dataset=df

listeu=dataset["p"]

dataset=dataset[-dataset["o"].isin(listeu)]

dataset=dataset[-dataset["o"].str.match(".*www.w3.org.*")]

pat = r'.*\/(.)'
dataset["s"]= dataset["s"].str.replace(pat,r'\1',regex=True)
dataset["o"]= dataset["o"].str.replace(pat,r'\1',regex=True)

dataset["o"]=dataset["o"].str.replace(".*#(.)",r'\1',regex=True)
dataset["s"]=dataset["s"].str.replace(".*#(.)",r'\1',regex=True)

lab=dataset[dataset["p"].isin(["http://www.w3.org/2000/01/rdf-schema#label","http://www.w3.org/2006/vcard/ns#fn"])]

labels=lab["s"].tolist()
urls=lab["o"].tolist()

dataset=pd.concat([lab, dataset]).drop_duplicates(keep=False)

dataset=dataset.replace(urls,labels)

dataset
# Out:
#                            o                                                p  \
# 33                       Aín  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 37                   BENIALI  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 41      Comunidad Valenciana  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 43                Plana_Baja  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 45    provincia de Castellón  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ...                      ...                                              ...
# 7561               LA BOLERA         http://www.w3.org/2006/vcard/ns#hasEmail
# 7562            CRYSTAL-PARK         http://www.w3.org/2006/vcard/ns#hasEmail
# 7563          NOU CASABLANCA         http://www.w3.org/2006/vcard/ns#hasEmail
# 7564        RH VINAROS PLAYA         http://www.w3.org/2006/vcard/ns#hasEmail
# 7565     HOSPEDERIA LA BALMA         http://www.w3.org/2006/vcard/ns#hasEmail
#
#                                          s
# 33                               Municipio
# 37                                   hotel
# 41                       ComunidadAutonoma
# 43                                 Comarca
# 45                               Provincia
# ...                                    ...
# 7561  hotelrestaurantelabolera@hotmail.com
# 7562            hotelcrystalpark@gmail.com
# 7563               noucasablanca@gmail.com
# 7564            vinarosplaya@hotelesrh.com
# 7565                  bealabalma@gmail.com
#
# [6975 rows x 3 columns]

# %% [markdown]
# understanding the difference between dataset and momo

# %%
pd.concat([momo,dataset]).drop_duplicates(keep=False)
# Out:
#             o                                         p    s
# 5634  node742  http://www.w3.org/2006/vcard/ns#locality  Ain
# 5634  node742  http://www.w3.org/2006/vcard/ns#locality  Aín

# %%
momo[momo["o"].str.match("node742")]
momo[momo["o"].str.match("A.n") | momo["s"].str.match("A.n")]
# Out:
#             o                                                  p  \
# 33        Aín    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 1203      Aín               http://www.w3.org/2002/07/owl#sameAs
# 2405      Aín  http://krono.act.uji.es/schemas/slodbi#num-apa...
# 2510      Aín  http://krono.act.uji.es/schemas/slodbi#plazas-...
# 2615      Aín  http://krono.act.uji.es/schemas/slodbi#tiene-h...
# 2785      Aín   http://krono.act.uji.es/schemas/slodbi#wd-entity
# 3234      Aín  http://krono.act.uji.es/vocabulary/slodbi#hasProv
# 3369      Aín  http://vocab.linkeddata.es/datosabiertos/def/s...
# 3513      Aín  http://vocab.linkeddata.es/datosabiertos/def/s...
# 3648      Aín  http://vocab.linkeddata.es/datosabiertos/def/s...
# 5634  node742           http://www.w3.org/2006/vcard/ns#locality
#
#                            s
# 33                 Municipio
# 1203                 Q735833
# 2405                       1
# 2510                       8
# 2615                 BENIALI
# 2785                 Q735833
# 3234          dipcas-dataset
# 3369    Comunidad Valenciana
# 3513              Plana_Baja
# 3648  provincia de Castellón
# 5634                     Ain

# %%
dataset[dataset["o"].str.match("node742")]
dataset[dataset["o"].str.match("A.n") | momo["s"].str.match("A.n")]
# Out:
#             o                                                  p  \
# 33        Aín    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 1203      Aín               http://www.w3.org/2002/07/owl#sameAs
# 2405      Aín  http://krono.act.uji.es/schemas/slodbi#num-apa...
# 2510      Aín  http://krono.act.uji.es/schemas/slodbi#plazas-...
# 2615      Aín  http://krono.act.uji.es/schemas/slodbi#tiene-h...
# 2785      Aín   http://krono.act.uji.es/schemas/slodbi#wd-entity
# 3234      Aín  http://krono.act.uji.es/vocabulary/slodbi#hasProv
# 3369      Aín  http://vocab.linkeddata.es/datosabiertos/def/s...
# 3513      Aín  http://vocab.linkeddata.es/datosabiertos/def/s...
# 3648      Aín  http://vocab.linkeddata.es/datosabiertos/def/s...
# 5634  node742           http://www.w3.org/2006/vcard/ns#locality
#
#                            s
# 33                 Municipio
# 1203                 Q735833
# 2405                       1
# 2510                       8
# 2615                 BENIALI
# 2785                 Q735833
# 3234          dipcas-dataset
# 3369    Comunidad Valenciana
# 3513              Plana_Baja
# 3648  provincia de Castellón
# 5634                     Aín

# %%
df[df["o"].str.match("node742")] #original
df[df["o"].str.match(".*A.n.*")] #original
df[df["o"].str.match(".*A.n.*") | momo["s"].str.match(".*A.n.*")]
# Out:
#                                                o  \
# 33    http://krono.act.uji.es/schemas/slodbi#Ain
# 1203  http://krono.act.uji.es/schemas/slodbi#Ain
# 1965  http://krono.act.uji.es/schemas/slodbi#Ain
# 2405  http://krono.act.uji.es/schemas/slodbi#Ain
# 2510  http://krono.act.uji.es/schemas/slodbi#Ain
# 2615  http://krono.act.uji.es/schemas/slodbi#Ain
# 2785  http://krono.act.uji.es/schemas/slodbi#Ain
# 3234  http://krono.act.uji.es/schemas/slodbi#Ain
# 3369  http://krono.act.uji.es/schemas/slodbi#Ain
# 3513  http://krono.act.uji.es/schemas/slodbi#Ain
# 3648  http://krono.act.uji.es/schemas/slodbi#Ain
# 5634                                     node742
#
#                                                       p  \
# 33      http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 1203               http://www.w3.org/2002/07/owl#sameAs
# 1965         http://www.w3.org/2000/01/rdf-schema#label
# 2405  http://krono.act.uji.es/schemas/slodbi#num-apa...
# 2510  http://krono.act.uji.es/schemas/slodbi#plazas-...
# 2615  http://krono.act.uji.es/schemas/slodbi#tiene-h...
# 2785   http://krono.act.uji.es/schemas/slodbi#wd-entity
# 3234  http://krono.act.uji.es/vocabulary/slodbi#hasProv
# 3369  http://vocab.linkeddata.es/datosabiertos/def/s...
# 3513  http://vocab.linkeddata.es/datosabiertos/def/s...
# 3648  http://vocab.linkeddata.es/datosabiertos/def/s...
# 5634           http://www.w3.org/2006/vcard/ns#locality
#
#                                                       s
# 33    http://vocab.linkeddata.es/datosabiertos/def/s...
# 1203             http://www.wikidata.org/entity/Q735833
# 1965                                                Aín
# 2405                                                  1
# 2510                                                  8
# 2615  http://krono.act.uji.es/schemas/slodbi#hotel-7...
# 2785             http://www.wikidata.org/entity/Q735833
# 3234  http://krono.act.uji.es/vocabulary/slodbi#dipc...
# 3369  http://krono.act.uji.es/schemas/slodbi#Comunid...
# 3513  http://krono.act.uji.es/schemas/slodbi#Plana_Baja
# 3648   http://krono.act.uji.es/schemas/slodbi#Castellon
# 5634                                                Ain

# %% [markdown]
# # Supression des sommets predicats

# %%
listeu=df["p"]
print(listeu)
df1=df[-df["o"].isin(listeu)]
df1
# Out:
# 0       http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 1       http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 2       http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 3       http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 4       http://www.w3.org/1999/02/22-rdf-syntax-ns#type
#                              ...
# 7561           http://www.w3.org/2006/vcard/ns#hasEmail
# 7562           http://www.w3.org/2006/vcard/ns#hasEmail
# 7563           http://www.w3.org/2006/vcard/ns#hasEmail
# 7564           http://www.w3.org/2006/vcard/ns#hasEmail
# 7565           http://www.w3.org/2006/vcard/ns#hasEmail
# Name: p, Length: 7566, dtype: object
#                                                       o  \
# 8      http://www.w3.org/2002/07/owl#equivalentProperty
# 9      http://www.w3.org/2002/07/owl#equivalentProperty
# 10        http://www.w3.org/2002/07/owl#equivalentClass
# 11        http://www.w3.org/2002/07/owl#equivalentClass
# 15    http://www.w3.org/1999/02/22-rdf-syntax-ns#sub...
# ...                                                 ...
# 7561  http://krono.act.uji.es/schemas/slodbi#hotel-7...
# 7562  http://krono.act.uji.es/schemas/slodbi#hotel-8...
# 7563  http://krono.act.uji.es/schemas/slodbi#hotel-9...
# 7564  http://krono.act.uji.es/schemas/slodbi#hotel-9...
# 7565  http://krono.act.uji.es/schemas/slodbi#hotel-c...
#
#                                                     p  \
# 8     http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 9     http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 10    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 11    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 15    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ...                                               ...
# 7561         http://www.w3.org/2006/vcard/ns#hasEmail
# 7562         http://www.w3.org/2006/vcard/ns#hasEmail
# 7563         http://www.w3.org/2006/vcard/ns#hasEmail
# 7564         http://www.w3.org/2006/vcard/ns#hasEmail
# 7565         http://www.w3.org/2006/vcard/ns#hasEmail
#
#                                                       s
# 8       http://www.w3.org/2002/07/owl#SymmetricProperty
# 9      http://www.w3.org/2002/07/owl#TransitiveProperty
# 10      http://www.w3.org/2002/07/owl#SymmetricProperty
# 11     http://www.w3.org/2002/07/owl#TransitiveProperty
# 15    http://www.w3.org/1999/02/22-rdf-syntax-ns#Pro...
# ...                                                 ...
# 7561               hotelrestaurantelabolera@hotmail.com
# 7562                         hotelcrystalpark@gmail.com
# 7563                            noucasablanca@gmail.com
# 7564                         vinarosplaya@hotelesrh.com
# 7565                               bealabalma@gmail.com
#
# [7460 rows x 3 columns]

# %%
df[df["o"].isin(df1["p"].tolist())]
# Out:
#                                                       o  \
# 0       http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 1     http://www.w3.org/2000/01/rdf-schema#subProper...
# 2     http://www.w3.org/2000/01/rdf-schema#subProper...
# 3       http://www.w3.org/2000/01/rdf-schema#subClassOf
# 4       http://www.w3.org/2000/01/rdf-schema#subClassOf
# ...                                                 ...
# 1202         http://www.w3.org/2000/01/rdf-schema#label
# 1956    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 1957  http://www.w3.org/2000/01/rdf-schema#subProper...
# 1958    http://www.w3.org/2000/01/rdf-schema#subClassOf
# 1963            http://www.w3.org/2002/07/owl#inverseOf
#
#                                                       p  \
# 0       http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 1       http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 2       http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 3       http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 4       http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ...                                                 ...
# 1202         http://www.w3.org/2000/01/rdf-schema#range
# 1956  http://proton.semanticweb.org/protonsys#transi...
# 1957  http://proton.semanticweb.org/protonsys#transi...
# 1958  http://proton.semanticweb.org/protonsys#transi...
# 1963            http://www.w3.org/2002/07/owl#inverseOf
#
#                                                       s
# 0     http://www.w3.org/1999/02/22-rdf-syntax-ns#Pro...
# 1     http://www.w3.org/1999/02/22-rdf-syntax-ns#Pro...
# 2      http://www.w3.org/2002/07/owl#TransitiveProperty
# 3     http://www.w3.org/1999/02/22-rdf-syntax-ns#Pro...
# 4      http://www.w3.org/2002/07/owl#TransitiveProperty
# ...                                                 ...
# 1202       http://www.w3.org/2000/01/rdf-schema#Literal
# 1956    http://www.w3.org/2000/01/rdf-schema#subClassOf
# 1957  http://www.w3.org/2000/01/rdf-schema#subProper...
# 1958    http://www.w3.org/2000/01/rdf-schema#subClassOf
# 1963            http://www.w3.org/2002/07/owl#inverseOf
#
# [106 rows x 3 columns]

# %%
df1[df1["o"].isin(df1["p"].tolist())]
# Out:
# Empty DataFrame
# Columns: [o, p, s]
# Index: []

# %%
df1[df1["o"].str.match(".*www.w3")].head()
# Out:
#                                                     o  \
# 8    http://www.w3.org/2002/07/owl#equivalentProperty
# 9    http://www.w3.org/2002/07/owl#equivalentProperty
# 10      http://www.w3.org/2002/07/owl#equivalentClass
# 11      http://www.w3.org/2002/07/owl#equivalentClass
# 15  http://www.w3.org/1999/02/22-rdf-syntax-ns#sub...
#
#                                                   p  \
# 8   http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 9   http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 10  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 11  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 15  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
#
#                                                     s
# 8     http://www.w3.org/2002/07/owl#SymmetricProperty
# 9    http://www.w3.org/2002/07/owl#TransitiveProperty
# 10    http://www.w3.org/2002/07/owl#SymmetricProperty
# 11   http://www.w3.org/2002/07/owl#TransitiveProperty
# 15  http://www.w3.org/1999/02/22-rdf-syntax-ns#Pro...

# %%
df1=df1[-df1["o"].str.match(".*www.w3.org.*")]
df1
# Out:
#                                                       o  \
# 33           http://krono.act.uji.es/schemas/slodbi#Ain
# 37    http://krono.act.uji.es/schemas/slodbi#hotel-7...
# 41    http://krono.act.uji.es/schemas/slodbi#Comunid...
# 43    http://krono.act.uji.es/schemas/slodbi#Plana_Baja
# 45     http://krono.act.uji.es/schemas/slodbi#Castellon
# ...                                                 ...
# 7561  http://krono.act.uji.es/schemas/slodbi#hotel-7...
# 7562  http://krono.act.uji.es/schemas/slodbi#hotel-8...
# 7563  http://krono.act.uji.es/schemas/slodbi#hotel-9...
# 7564  http://krono.act.uji.es/schemas/slodbi#hotel-9...
# 7565  http://krono.act.uji.es/schemas/slodbi#hotel-c...
#
#                                                     p  \
# 33    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 37    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 41    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 43    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 45    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ...                                               ...
# 7561         http://www.w3.org/2006/vcard/ns#hasEmail
# 7562         http://www.w3.org/2006/vcard/ns#hasEmail
# 7563         http://www.w3.org/2006/vcard/ns#hasEmail
# 7564         http://www.w3.org/2006/vcard/ns#hasEmail
# 7565         http://www.w3.org/2006/vcard/ns#hasEmail
#
#                                                       s
# 33    http://vocab.linkeddata.es/datosabiertos/def/s...
# 37         http://krono.act.uji.es/schemas/slodbi#hotel
# 41    http://vocab.linkeddata.es/datosabiertos/def/s...
# 43    http://vocab.linkeddata.es/datosabiertos/def/s...
# 45    http://vocab.linkeddata.es/datosabiertos/def/s...
# ...                                                 ...
# 7561               hotelrestaurantelabolera@hotmail.com
# 7562                         hotelcrystalpark@gmail.com
# 7563                            noucasablanca@gmail.com
# 7564                         vinarosplaya@hotelesrh.com
# 7565                               bealabalma@gmail.com
#
# [7416 rows x 3 columns]

# %% [markdown]
# # couleur tentative échouée

# %%
"""
df1["color"]="#fffd9e"

df1.loc[df1["o"].str.match(".*node.*"),"color"]="#6B0504"
df1.loc[df1["o"].str.match(".*hotel.*"),"color"]="#2B59C3"
df1.loc[df1["o"].str.match(".*empresa-turismo.*"),"color"]="#D36582"
df1.loc[df1["o"].str.match(".*albergue.*"),"color"]="#C9A690"


df1.sample(20)
df1[df1["o"].str.match("node366.*")]

"""
# Out:
# '\ndf1["color"]="#fffd9e"\n\ndf1.loc[df1["o"].str.match(".*node.*"),"color"]="#6B0504"\ndf1.loc[df1["o"].str.match(".*hotel.*"),"color"]="#2B59C3"\ndf1.loc[df1["o"].str.match(".*empresa-turismo.*"),"color"]="#D36582"\ndf1.loc[df1["o"].str.match(".*albergue.*"),"color"]="#C9A690"\n\n\ndf1.sample(20)\ndf1[df1["o"].str.match("node366.*")]\n\n'

# %% [markdown]
# # NETTOYAGE URL

# %%
pat = r'.*\/(.)'
df1["s"]= df1["s"].str.replace(pat,r'\1',regex=True)
df1["o"]= df1["o"].str.replace(pat,r'\1',regex=True)
df1
# Out:
# C:\Users\gmati\AppData\Local\Temp\ipykernel_8524\126304514.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["s"]= df1["s"].str.replace(pat,r'\1',regex=True)
# C:\Users\gmati\AppData\Local\Temp\ipykernel_8524\126304514.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["o"]= df1["o"].str.replace(pat,r'\1',regex=True)
#                                                       o  \
# 33                                           slodbi#Ain
# 37    slodbi#hotel-7a2575c0543108e27c8ebf3cdf705d98e...
# 41                          slodbi#Comunidad_Valenciana
# 43                                    slodbi#Plana_Baja
# 45                                     slodbi#Castellon
# ...                                                 ...
# 7561  slodbi#hotel-794e9b67799c1affdc9cacce8439a9b53...
# 7562  slodbi#hotel-80b917fa788e75b5e8de2102d32fb80da...
# 7563  slodbi#hotel-97c90348c8f61ecf6b5a326af9a025d12...
# 7564  slodbi#hotel-9aa7d04691c8b162dc59de7bc00038d6a...
# 7565  slodbi#hotel-ce4822401290083e77640dc6797745a97...
#
#                                                     p  \
# 33    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 37    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 41    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 43    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 45    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ...                                               ...
# 7561         http://www.w3.org/2006/vcard/ns#hasEmail
# 7562         http://www.w3.org/2006/vcard/ns#hasEmail
# 7563         http://www.w3.org/2006/vcard/ns#hasEmail
# 7564         http://www.w3.org/2006/vcard/ns#hasEmail
# 7565         http://www.w3.org/2006/vcard/ns#hasEmail
#
#                                          s
# 33                    territorio#Municipio
# 37                            slodbi#hotel
# 41            territorio#ComunidadAutonoma
# 43                      territorio#Comarca
# 45                    territorio#Provincia
# ...                                    ...
# 7561  hotelrestaurantelabolera@hotmail.com
# 7562            hotelcrystalpark@gmail.com
# 7563               noucasablanca@gmail.com
# 7564            vinarosplaya@hotelesrh.com
# 7565                  bealabalma@gmail.com
#
# [7416 rows x 3 columns]

# %%
df[df["o"].str.match(".*albergue.*")]
# Out:
#                                                       o  \
# 76    http://krono.act.uji.es/schemas/slodbi#tiene-a...
# 77    http://krono.act.uji.es/schemas/slodbi#albergu...
# 86    http://krono.act.uji.es/schemas/slodbi#albergu...
# 216   http://krono.act.uji.es/schemas/slodbi#albergu...
# 221   http://krono.act.uji.es/schemas/slodbi#albergu...
# ...                                                 ...
# 6987  http://krono.act.uji.es/schemas/slodbi#albergu...
# 6988  http://krono.act.uji.es/schemas/slodbi#albergu...
# 6989  http://krono.act.uji.es/schemas/slodbi#albergu...
# 6991  http://krono.act.uji.es/schemas/slodbi#albergu...
# 6992  http://krono.act.uji.es/schemas/slodbi#albergu...
#
#                                                     p  \
# 76    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 77    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 86    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 216   http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 221   http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ...                                               ...
# 6987              http://www.w3.org/2006/vcard/ns#url
# 6988              http://www.w3.org/2006/vcard/ns#url
# 6989              http://www.w3.org/2006/vcard/ns#url
# 6991              http://www.w3.org/2006/vcard/ns#url
# 6992              http://www.w3.org/2006/vcard/ns#url
#
#                                                       s
# 76    http://www.w3.org/1999/02/22-rdf-syntax-ns#Pro...
# 77      http://krono.act.uji.es/schemas/slodbi#albergue
# 86      http://krono.act.uji.es/schemas/slodbi#albergue
# 216     http://krono.act.uji.es/schemas/slodbi#albergue
# 221     http://krono.act.uji.es/schemas/slodbi#albergue
# ...                                                 ...
# 6987                                http://vallibona.es
# 6988                            http://www.vilafames.es
# 6989                           http://www.laparreta.com
# 6991                       http://www.elmasdeborras.com
# 6992                      http://www.mardelacarrasca.es
#
# [187 rows x 3 columns]

# %%
lab=df1[df1["p"].isin(["http://www.w3.org/2000/01/rdf-schema#label","http://www.w3.org/2006/vcard/ns#fn"])]

labels=lab["s"].tolist()
urls=lab["o"].tolist()

lab
# Out:
#                                                       o  \
# 1965                                         slodbi#Ain
# 1966                        slodbi#Comunidad_Valenciana
# 1967                                   slodbi#Castellon
# 1968                                  slodbi#Albocasser
# 1969                            slodbi#Alcala_de_Xivert
# ...                                                 ...
# 4836  slodbi#empresa-turismo-activo-b8e797b9324c5126...
# 4837  slodbi#hotel-a6fce53c479eea7ad373abbe733843b85...
# 4838  slodbi#empresa-turismo-activo-5ffe966fb623d602...
# 4839  slodbi#hotel-ce4822401290083e77640dc6797745a97...
# 4840  slodbi#hotel-d8c50e4eb2b9c81ec522954f6c105de29...
#
#                                                p                            s
# 1965  http://www.w3.org/2000/01/rdf-schema#label                          Aín
# 1966  http://www.w3.org/2000/01/rdf-schema#label         Comunidad Valenciana
# 1967  http://www.w3.org/2000/01/rdf-schema#label       provincia de Castellón
# 1968  http://www.w3.org/2000/01/rdf-schema#label                   Albocàsser
# 1969  http://www.w3.org/2000/01/rdf-schema#label             Alcalà de Xivert
# ...                                          ...                          ...
# 4836          http://www.w3.org/2006/vcard/ns#fn  PERSENDA ESPORTS D'AVENTURA
# 4837          http://www.w3.org/2006/vcard/ns#fn               VILLA DE VIVER
# 4838          http://www.w3.org/2006/vcard/ns#fn              TRACKS MAESTRAT
# 4839          http://www.w3.org/2006/vcard/ns#fn          HOSPEDERIA LA BALMA
# 4840          http://www.w3.org/2006/vcard/ns#fn                 MEDITERRANEO
#
# [441 rows x 3 columns]

# %%
dup=lab[lab["s"].duplicated()]
lab[lab["s"].isin(dup["s"])]
#EL FAIXERO
df1[df1["o"].isin(df1[df1["s"]=="EL FAIXERO"]["o"])]
#node72 TELEPHONE
#node872 TELEPHONE
#node70 ADRESS
#node870 ADRESSS

df[df["o"].isin(["node872","node72","node70","node870"])]
#deux adresses différentes
#same phone number

# il faut les appeler différément
# Out:
#             o                                                p  \
# 551    node72  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 960   node872  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 5162   node70  http://krono.act.uji.es/schemas/slodbi#locality
# 5362  node870  http://krono.act.uji.es/schemas/slodbi#locality
# 5466   node70         http://www.w3.org/2006/vcard/ns#locality
# 5666  node870         http://www.w3.org/2006/vcard/ns#locality
# 5770   node70      http://www.w3.org/2006/vcard/ns#postal-code
# 5946  node870      http://www.w3.org/2006/vcard/ns#postal-code
# 6030   node70   http://www.w3.org/2006/vcard/ns#street-address
# 6230  node870   http://www.w3.org/2006/vcard/ns#street-address
# 6638   node72         http://www.w3.org/2006/vcard/ns#hasValue
# 6838  node872         http://www.w3.org/2006/vcard/ns#hasValue
#
#                                           s
# 551   http://www.w3.org/2006/vcard/ns#Voice
# 960   http://www.w3.org/2006/vcard/ns#Voice
# 5162                                 node71
# 5362                                node871
# 5466                             Cinctorres
# 5666                             Cinctorres
# 5770                                  12318
# 5946                                  12318
# 6030                      CR LA IGLESUELA 7
# 6230                       C SAN LUIS 59-63
# 6638                          tel:964181075
# 6838                          tel:964181075

# %%
#dup=lab[lab["s"].duplicated()]
lab[lab["s"].isin(dup["s"])]
# Out:
#                                                       o  \
# 4598  slodbi#hotel-b6b3d402bdccd6f9464f63db9242b2089...
# 4652  slodbi#hotel-ea875070569331701d1e8543d919404d4...
# 4655  slodbi#albergue-b4619d5f34e51da488f9fb19ebb8e8...
# 4657  slodbi#hotel-a377b0efafad52f870ecb53baf99ee4bd...
# 4674  slodbi#albergue-301edb33dc7276e7346e6cab110788...
# 4675  slodbi#albergue-82bfe9a537b6f67b814b617d7949b4...
# 4689  slodbi#hotel-feeaceefcc18b61940ef99a53fa5401d9...
# 4702  slodbi#hotel-6bb2e7219ed7a10e17133e9cff88b93dd...
# 4712  slodbi#hotel-1fc077aa276d36d3b717d7c9462d2287c...
# 4723  slodbi#hotel-03c12f74a0d889d106ab42f730b2375a3...
# 4735  slodbi#hotel-00409b23b314e4c279b74321c861e2872...
# 4744  slodbi#hotel-4a5803404660f9b81311404a6b668eb78...
# 4818  slodbi#albergue-3a2898bf67bc27a220580061867d97...
# 4820  slodbi#empresa-turismo-activo-9fa5950eb00ceb3f...
#
#                                        p                   s
# 4598  http://www.w3.org/2006/vcard/ns#fn             VORAMAR
# 4652  http://www.w3.org/2006/vcard/ns#fn             JAIME I
# 4655  http://www.w3.org/2006/vcard/ns#fn          EL FAIXERO
# 4657  http://www.w3.org/2006/vcard/ns#fn          EL FAIXERO
# 4674  http://www.w3.org/2006/vcard/ns#fn  ALBERGUE EL DHARMA
# 4675  http://www.w3.org/2006/vcard/ns#fn  ALBERGUE EL DHARMA
# 4689  http://www.w3.org/2006/vcard/ns#fn              EL CID
# 4702  http://www.w3.org/2006/vcard/ns#fn             VORAMAR
# 4712  http://www.w3.org/2006/vcard/ns#fn              MARINA
# 4723  http://www.w3.org/2006/vcard/ns#fn              EL CID
# 4735  http://www.w3.org/2006/vcard/ns#fn              MARINA
# 4744  http://www.w3.org/2006/vcard/ns#fn             JAIME I
# 4818  http://www.w3.org/2006/vcard/ns#fn       MAS DE BORRAS
# 4820  http://www.w3.org/2006/vcard/ns#fn       MAS DE BORRAS

# %%
df2=pd.concat([lab, df1]).drop_duplicates(keep=False)

# %%
newlabels=[]
tempo={}
for lab in labels:
    if lab in tempo:
        tempo[lab]=tempo[lab]+1
        newlabels.append(lab+'('+str(tempo[lab])+')')
    else:
        tempo[lab]=0
        newlabels.append(lab)

# %%
df3=df2.replace(urls,newlabels)
df3[df3["o"].str.match(".*JAIME.*")]
# Out:
#                   o                                                  p  \
# 212         JAIME I    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 282   REY DON JAIME    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 346      JAIME I(1)    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 1365        JAIME I               http://www.w3.org/2002/07/owl#sameAs
# 1435  REY DON JAIME               http://www.w3.org/2002/07/owl#sameAs
# 1499     JAIME I(1)               http://www.w3.org/2002/07/owl#sameAs
# 4085        JAIME I  http://krono.act.uji.es/schemas/slodbi#categor...
# 4109  REY DON JAIME  http://krono.act.uji.es/schemas/slodbi#categor...
# 4151     JAIME I(1)  http://krono.act.uji.es/schemas/slodbi#categor...
# 4349        JAIME I   http://krono.act.uji.es/schemas/slodbi#ubicacion
# 4385  REY DON JAIME   http://krono.act.uji.es/schemas/slodbi#ubicacion
# 4440     JAIME I(1)   http://krono.act.uji.es/schemas/slodbi#ubicacion
# 4956        JAIME I         http://www.w3.org/2006/vcard/ns#hasAddress
# 4992  REY DON JAIME         http://www.w3.org/2006/vcard/ns#hasAddress
# 5048     JAIME I(1)         http://www.w3.org/2006/vcard/ns#hasAddress
# 6432        JAIME I       http://www.w3.org/2006/vcard/ns#hasTelephone
# 6468  REY DON JAIME       http://www.w3.org/2006/vcard/ns#hasTelephone
# 6524     JAIME I(1)       http://www.w3.org/2006/vcard/ns#hasTelephone
# 7081        JAIME I  http://krono.act.uji.es/schemas/slodbi#habitac...
# 7096  REY DON JAIME  http://krono.act.uji.es/schemas/slodbi#habitac...
# 7123     JAIME I(1)  http://krono.act.uji.es/schemas/slodbi#habitac...
# 7267        JAIME I      http://krono.act.uji.es/schemas/slodbi#plazas
# 7284  REY DON JAIME      http://krono.act.uji.es/schemas/slodbi#plazas
# 7326     JAIME I(1)      http://krono.act.uji.es/schemas/slodbi#plazas
# 7463        JAIME I           http://www.w3.org/2006/vcard/ns#hasEmail
# 7478  REY DON JAIME           http://www.w3.org/2006/vcard/ns#hasEmail
# 7506     JAIME I(1)           http://www.w3.org/2006/vcard/ns#hasEmail
#
#                                               s
# 212                                slodbi#hotel
# 282                                slodbi#hotel
# 346                                slodbi#hotel
# 1365  ea875070569331701d1e8543d919404d4f93cb3c/
# 1435  f8ee71c19e02085c5b57ed5843356be44ca7c26f/
# 1499  4a5803404660f9b81311404a6b668eb787f04323/
# 4085                                          3
# 4109                                          3
# 4151                                          3
# 4349                                   node1128
# 4385                                   node1184
# 4440                                    node605
# 4956                                   node1129
# 4992                                   node1185
# 5048                                    node606
# 6432                                   node1131
# 6468                                   node1187
# 6524                                    node608
# 7081                                         89
# 7096                                         44
# 7123                                         47
# 7267                                        166
# 7284                                         83
# 7326                                         91
# 7463                       info@hoteljaimei.com
# 7478               hotel@reydonjaimemorella.com
# 7506       informacion@hoteljaimeipeniscola.com

# %%
print(df2[df2["s"]=="node473"])
print("-------")
print(df2[df2["o"]=="node473"])
# Out:
#                                                       o  \
# 4409  slodbi#hotel-1fc077aa276d36d3b717d7c9462d2287c...
#
#                                                      p        s
# 4409  http://krono.act.uji.es/schemas/slodbi#ubicacion  node473
# -------
#             o                                                p  \
# 761   node473  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 2220  node473       http://www.opengis.net/ont/geosparql#asWKT
#
#                                               s
# 761                                    sf#Point
# 2220  POINT(40.09360759100008 0.12244000000004)

# %%
tab=df3[df3["s"]=="territorio#Comarca"]
coma=tab["o"]
coma=coma.tolist()

df3[df3["o"].isin(coma)]
# Out:
#                                   o  \
# 43                slodbi#Plana_Baja
# 47           slodbi#Alto_Maestrazgo
# 70           slodbi#Bajo_Maestrazgo
# 73                 slodbi#Alcalaten
# 81             slodbi#Alto_Palancia
# 84                slodbi#Plana_Alta
# 95              slodbi#Alto_Mijares
# 178   slodbi#Los_Puertos_de_Morella
# 1206              slodbi#Plana_Baja
# 1209         slodbi#Alto_Maestrazgo
# 1225         slodbi#Bajo_Maestrazgo
# 1227               slodbi#Alcalaten
# 1234           slodbi#Alto_Palancia
# 1237              slodbi#Plana_Alta
# 1248            slodbi#Alto_Mijares
# 1331  slodbi#Los_Puertos_de_Morella
# 2787              slodbi#Plana_Baja
# 2790         slodbi#Alto_Maestrazgo
# 2792         slodbi#Bajo_Maestrazgo
# 2794               slodbi#Alcalaten
# 2798           slodbi#Alto_Palancia
# 2800              slodbi#Plana_Alta
# 2806            slodbi#Alto_Mijares
# 2829  slodbi#Los_Puertos_de_Morella
# 3370              slodbi#Plana_Baja
# 3373         slodbi#Alto_Maestrazgo
# 3375         slodbi#Bajo_Maestrazgo
# 3377               slodbi#Alcalaten
# 3381           slodbi#Alto_Palancia
# 3383              slodbi#Plana_Alta
# 3389            slodbi#Alto_Mijares
# 3412  slodbi#Los_Puertos_de_Morella
# 3649              slodbi#Plana_Baja
# 3651         slodbi#Alto_Maestrazgo
# 3653         slodbi#Bajo_Maestrazgo
# 3655               slodbi#Alcalaten
# 3659           slodbi#Alto_Palancia
# 3661              slodbi#Plana_Alta
# 3667            slodbi#Alto_Mijares
# 3690  slodbi#Los_Puertos_de_Morella
#
#                                                       p  \
# 43      http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 47      http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 70      http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 73      http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 81      http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 84      http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 95      http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 178     http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 1206               http://www.w3.org/2002/07/owl#sameAs
# 1209               http://www.w3.org/2002/07/owl#sameAs
# 1225               http://www.w3.org/2002/07/owl#sameAs
# 1227               http://www.w3.org/2002/07/owl#sameAs
# 1234               http://www.w3.org/2002/07/owl#sameAs
# 1237               http://www.w3.org/2002/07/owl#sameAs
# 1248               http://www.w3.org/2002/07/owl#sameAs
# 1331               http://www.w3.org/2002/07/owl#sameAs
# 2787   http://krono.act.uji.es/schemas/slodbi#wd-entity
# 2790   http://krono.act.uji.es/schemas/slodbi#wd-entity
# 2792   http://krono.act.uji.es/schemas/slodbi#wd-entity
# 2794   http://krono.act.uji.es/schemas/slodbi#wd-entity
# 2798   http://krono.act.uji.es/schemas/slodbi#wd-entity
# 2800   http://krono.act.uji.es/schemas/slodbi#wd-entity
# 2806   http://krono.act.uji.es/schemas/slodbi#wd-entity
# 2829   http://krono.act.uji.es/schemas/slodbi#wd-entity
# 3370  http://vocab.linkeddata.es/datosabiertos/def/s...
# 3373  http://vocab.linkeddata.es/datosabiertos/def/s...
# 3375  http://vocab.linkeddata.es/datosabiertos/def/s...
# 3377  http://vocab.linkeddata.es/datosabiertos/def/s...
# 3381  http://vocab.linkeddata.es/datosabiertos/def/s...
# 3383  http://vocab.linkeddata.es/datosabiertos/def/s...
# 3389  http://vocab.linkeddata.es/datosabiertos/def/s...
# 3412  http://vocab.linkeddata.es/datosabiertos/def/s...
# 3649  http://vocab.linkeddata.es/datosabiertos/def/s...
# 3651  http://vocab.linkeddata.es/datosabiertos/def/s...
# 3653  http://vocab.linkeddata.es/datosabiertos/def/s...
# 3655  http://vocab.linkeddata.es/datosabiertos/def/s...
# 3659  http://vocab.linkeddata.es/datosabiertos/def/s...
# 3661  http://vocab.linkeddata.es/datosabiertos/def/s...
# 3667  http://vocab.linkeddata.es/datosabiertos/def/s...
# 3690  http://vocab.linkeddata.es/datosabiertos/def/s...
#
#                            s
# 43        territorio#Comarca
# 47        territorio#Comarca
# 70        territorio#Comarca
# 73        territorio#Comarca
# 81        territorio#Comarca
# 84        territorio#Comarca
# 95        territorio#Comarca
# 178       territorio#Comarca
# 1206                Q2300704
# 1209                Q2247639
# 1225                 Q804017
# 1227                Q2300724
# 1234                Q2300713
# 1237                Q1949333
# 1248                Q2300630
# 1331                Q2248089
# 2787                Q2300704
# 2790                Q2247639
# 2792                 Q804017
# 2794                Q2300724
# 2798                Q2300713
# 2800                Q1949333
# 2806                Q2300630
# 2829                Q2248089
# 3370    Comunidad Valenciana
# 3373    Comunidad Valenciana
# 3375    Comunidad Valenciana
# 3377    Comunidad Valenciana
# 3381    Comunidad Valenciana
# 3383    Comunidad Valenciana
# 3389    Comunidad Valenciana
# 3412    Comunidad Valenciana
# 3649  provincia de Castellón
# 3651  provincia de Castellón
# 3653  provincia de Castellón
# 3655  provincia de Castellón
# 3659  provincia de Castellón
# 3661  provincia de Castellón
# 3667  provincia de Castellón
# 3690  provincia de Castellón

# %%
df3[df3["o"].str.match(".*CIRCUITO.*")]
# Out:
#                                    o  \
# 277   CIRCUITO DE AVENTURA SALTAPINS
# 1430  CIRCUITO DE AVENTURA SALTAPINS
# 4380  CIRCUITO DE AVENTURA SALTAPINS
# 4987  CIRCUITO DE AVENTURA SALTAPINS
# 6463  CIRCUITO DE AVENTURA SALTAPINS
# 6966  CIRCUITO DE AVENTURA SALTAPINS
#
#                                                      p  \
# 277    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 1430              http://www.w3.org/2002/07/owl#sameAs
# 4380  http://krono.act.uji.es/schemas/slodbi#ubicacion
# 4987        http://www.w3.org/2006/vcard/ns#hasAddress
# 6463      http://www.w3.org/2006/vcard/ns#hasTelephone
# 6966               http://www.w3.org/2006/vcard/ns#url
#
#                                               s
# 277               slodbi#empresa-turismo-activo
# 1430  12cc2298d04078ad585ffe4287aec35dd12693cc/
# 4380                                    node109
# 4987                                    node110
# 6463                                    node112
# 6966                              saltapins.com

# %%
df3["o"]=df3["o"].str.replace(".*#(.)",r'\1',regex=True)
df3["s"]=df3["s"].str.replace(".*#(.)",r'\1',regex=True)
df3
# Out:
#                            o                                                p  \
# 33                       Aín  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 37                   BENIALI  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 41      Comunidad Valenciana  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 43                Plana_Baja  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 45    provincia de Castellón  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ...                      ...                                              ...
# 7561               LA BOLERA         http://www.w3.org/2006/vcard/ns#hasEmail
# 7562            CRYSTAL-PARK         http://www.w3.org/2006/vcard/ns#hasEmail
# 7563          NOU CASABLANCA         http://www.w3.org/2006/vcard/ns#hasEmail
# 7564        RH VINAROS PLAYA         http://www.w3.org/2006/vcard/ns#hasEmail
# 7565     HOSPEDERIA LA BALMA         http://www.w3.org/2006/vcard/ns#hasEmail
#
#                                          s
# 33                               Municipio
# 37                                   hotel
# 41                       ComunidadAutonoma
# 43                                 Comarca
# 45                               Provincia
# ...                                    ...
# 7561  hotelrestaurantelabolera@hotmail.com
# 7562            hotelcrystalpark@gmail.com
# 7563               noucasablanca@gmail.com
# 7564            vinarosplaya@hotelesrh.com
# 7565                  bealabalma@gmail.com
#
# [6975 rows x 3 columns]

# %%
df3[df3.duplicated()]
# Out:
# Empty DataFrame
# Columns: [o, p, s]
# Index: []

# %%
df3[df3["o"].str.match(".*MAS DE BORRAS.*")]
# Out:
#                      o                                                  p  \
# 466      MAS DE BORRAS    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 468   MAS DE BORRAS(1)    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 1619     MAS DE BORRAS               http://www.w3.org/2002/07/owl#sameAs
# 1621  MAS DE BORRAS(1)               http://www.w3.org/2002/07/owl#sameAs
# 4219     MAS DE BORRAS  http://krono.act.uji.es/schemas/slodbi#categor...
# 4514     MAS DE BORRAS   http://krono.act.uji.es/schemas/slodbi#ubicacion
# 4516  MAS DE BORRAS(1)   http://krono.act.uji.es/schemas/slodbi#ubicacion
# 5122     MAS DE BORRAS         http://www.w3.org/2006/vcard/ns#hasAddress
# 5124  MAS DE BORRAS(1)         http://www.w3.org/2006/vcard/ns#hasAddress
# 6598     MAS DE BORRAS       http://www.w3.org/2006/vcard/ns#hasTelephone
# 6600  MAS DE BORRAS(1)       http://www.w3.org/2006/vcard/ns#hasTelephone
# 6991     MAS DE BORRAS                http://www.w3.org/2006/vcard/ns#url
# 6993  MAS DE BORRAS(1)                http://www.w3.org/2006/vcard/ns#url
#
#                                               s
# 466                                    albergue
# 468                      empresa-turismo-activo
# 1619  3a2898bf67bc27a220580061867d977f9b17c708/
# 1621  9fa5950eb00ceb3f4a6d7c013dff0ce4730f51e3/
# 4219                                          E
# 4514                                     node29
# 4516                                    node273
# 5122                                     node30
# 5124                                    node274
# 6598                                     node32
# 6600                                    node276
# 6991                      www.elmasdeborras.com
# 6993                      www.elmasdeborras.com

# %%
# Out:
#                          o                                                  p  \
# 1644        VILLA DE VIVER               http://www.w3.org/2002/07/owl#sameAs
# 2833                  Catí   http://krono.act.uji.es/schemas/slodbi#wd-entity
# 566        dipcas-opendata    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 996                node944    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 4906            TRAMONTANA         http://www.w3.org/2006/vcard/ns#hasAddress
# 55          LAS MORERAS AC    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 5701              node1010           http://www.w3.org/2006/vcard/ns#locality
# 1669                node71               http://www.w3.org/2002/07/owl#sameAs
# 5881               node550        http://www.w3.org/2006/vcard/ns#postal-code
# 390                Sacañet    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 7244  CAMPING TORRE LA SAL      http://krono.act.uji.es/schemas/slodbi#plazas
# 5578               node518           http://www.w3.org/2006/vcard/ns#locality
# 7468       ROSALEDA DONCEL           http://www.w3.org/2006/vcard/ns#hasEmail
# 977                node905    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 1951              node1198               http://www.w3.org/2002/07/owl#sameAs
# 5957               node934        http://www.w3.org/2006/vcard/ns#postal-code
# 688                node333    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 6854               node936           http://www.w3.org/2006/vcard/ns#hasValue
# 6594                LLOSAR       http://www.w3.org/2006/vcard/ns#hasTelephone
# 2711       Oropesa del Mar  http://krono.act.uji.es/schemas/slodbi#tiene-h...
#
#                                               s    color
# 1644  a6fce53c479eea7ad373abbe733843b854789a22/  #000000
# 2833                                   Q1645833  #000000
# 566                                      Entity  #000000
# 996                                       Voice  #fffd9e
# 4906                                   node1078  #000000
# 55                                        hotel  #000000
# 5701                              Alfondeguilla  #fffd9e
# 1669                                   Q1646167  #fffd9e
# 5881                                      12428  #fffd9e
# 390                                   Municipio  #000000
# 7244                                        517  #000000
# 5578                     Pobla de Benifassà, la  #fffd9e
# 7468                 doncel@hotelesrosaleda.com  #000000
# 977                                       Point  #fffd9e
# 1951                                   Q1635650  #fffd9e
# 5957                                      12598  #fffd9e
# 688                                       Point  #fffd9e
# 6854                              tel:964480659  #fffd9e
# 6594                                    node908  #000000
# 2711               Hotel Servigroup Koral Beach  #000000

# %% [markdown]
# # TACHE 2 GENERATION DE REQUETES SPARQL

# %%
sparql = SPARQLWrapper(
    "http://LAPTOP-CS19OKIS:7200/repositories/tach1"
)
sparql.setReturnFormat(JSON)

queryString4="""
SELECT ?o ?p ?s WHERE{
    # ?o ?p ?s
    }

"""

# %%
sparql.setQuery(queryString4)

test=[]
dataf={}
try:
    ret = sparql.queryAndConvert()     
except Exception as e:
    print(e)

dataf['o']=[]
dataf['p']=[]
dataf['s']=[]
for r in ret["results"]["bindings"]:
    #print(r)
    #print(r["O"]["value"])
    dataf['o'].append(r['o']["value"])
    dataf['p'].append(r['p']["value"])
    dataf['s'].append(r['s']["value"])
    if r['o']["value"] not in test:
        test.append(r['o']["value"])
    if r["s"]["value"] not in test:    
        test.append(r["s"]["value"])    

df=pd.DataFrame(dataf)

# %% [markdown]
# creation de dataframe pour la réponse de requète

# %%
dataframe=pd.DataFrame(ret["results"]["bindings"])
cleandata={}

for l in dataframe.columns:
    cleandata[l]=[]
    

ret["results"]["bindings"]
for r in ret["results"]["bindings"]:
    for l in dataframe.columns:
        cleandata[l].append(r[l]["value"])

dataframe=pd.DataFrame(cleandata)
dataframe
# Out:
#                                                       o  \
# 0       http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 1     http://www.w3.org/2000/01/rdf-schema#subProper...
# 2     http://www.w3.org/2000/01/rdf-schema#subProper...
# 3       http://www.w3.org/2000/01/rdf-schema#subClassOf
# 4       http://www.w3.org/2000/01/rdf-schema#subClassOf
# ...                                                 ...
# 7561  http://krono.act.uji.es/schemas/slodbi#hotel-7...
# 7562  http://krono.act.uji.es/schemas/slodbi#hotel-8...
# 7563  http://krono.act.uji.es/schemas/slodbi#hotel-9...
# 7564  http://krono.act.uji.es/schemas/slodbi#hotel-9...
# 7565  http://krono.act.uji.es/schemas/slodbi#hotel-c...
#
#                                                     p  \
# 0     http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 1     http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 2     http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 3     http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 4     http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# ...                                               ...
# 7561         http://www.w3.org/2006/vcard/ns#hasEmail
# 7562         http://www.w3.org/2006/vcard/ns#hasEmail
# 7563         http://www.w3.org/2006/vcard/ns#hasEmail
# 7564         http://www.w3.org/2006/vcard/ns#hasEmail
# 7565         http://www.w3.org/2006/vcard/ns#hasEmail
#
#                                                       s
# 0     http://www.w3.org/1999/02/22-rdf-syntax-ns#Pro...
# 1     http://www.w3.org/1999/02/22-rdf-syntax-ns#Pro...
# 2      http://www.w3.org/2002/07/owl#TransitiveProperty
# 3     http://www.w3.org/1999/02/22-rdf-syntax-ns#Pro...
# 4      http://www.w3.org/2002/07/owl#TransitiveProperty
# ...                                                 ...
# 7561               hotelrestaurantelabolera@hotmail.com
# 7562                         hotelcrystalpark@gmail.com
# 7563                            noucasablanca@gmail.com
# 7564                         vinarosplaya@hotelesrh.com
# 7565                               bealabalma@gmail.com
#
# [7566 rows x 3 columns]

# %%
def answer_df(query):

    sparql.setQuery(query)

    try:
        ret = sparql.queryAndConvert()     
    except Exception as e:
        print(e)

    dataframe=pd.DataFrame(ret["results"]["bindings"])
    cleandata={}

    for l in dataframe.columns:
        cleandata[l]=[]
    
    for r in ret["results"]["bindings"]:
        for l in dataframe.columns:
            cleandata[l].append(r[l]["value"])

    dataframe=pd.DataFrame(cleandata)
    return dataframe

# %%
bigquery="""
SELECT ?o ?p ?s WHERE{
    # ?o ?p ?s
    }
LIMIT 600

"""
#tiene-hoteles
#tiene-campings
#tiene-albergues
#tiene-empresas-de-turismo-activo

def query_func(qr_variable="?pp",qr_variable1="?s1"):
    if qr_variable1 != "?s1":
        qr_variable1="'"+qr_variable1+"'"
    if qr_variable != "?pp":
        qr_variable="slodbi:"+qr_variable
    
    q="""
    PREFIX slodbi: <http://krono.act.uji.es/schemas/slodbi#>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX vcard: <http://www.w3.org/2006/vcard/ns#>
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    
    SELECT ?s1 ?s3 ?type
    WHERE{
    # ?o rdfs:label """+qr_variable1+""".
    # ?o """+qr_variable+""" ?s2.
    # ?s2 vcard:fn ?s3.
    # ?s2 rdf:type ?type.
    }
    
    """
    return q
    
#I want all the hotels  
query=query_func("tiene-campings")   
print(query)
# Out:
#     PREFIX slodbi: <http://krono.act.uji.es/schemas/slodbi#>
#     PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
#     PREFIX vcard: <http://www.w3.org/2006/vcard/ns#>
#     PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
#
#     SELECT ?s1 ?s3 ?type
#     WHERE{
#     ?o rdfs:label ?s1.
#     ?o slodbi:tiene-campings ?s2.
#     ?s2 vcard:fn ?s3.
#     ?s2 rdf:type ?type.
#     }

# %%
#automatiser l'ajout des prefixes ? 
doow=answer_df(query)
doow
#doow=doow[-doow["o"].str.match(".*www.w3.org.*")]
# Out:
#                         s1                          s3  \
# 0         Alcalà de Xivert              LAS MORERAS AC
# 1         Alcalà de Xivert                     RIBAMAR
# 2         Alcalà de Xivert             PLAYA TROPICANA
# 3         Alcalà de Xivert     LOS OLIVOS CAMPING PARK
# 4                   Altura           CAMPING MUNICIPAL
# 5                    Bejís                LOS CLOTICOS
# 6                Benicarló             ALEGRIA DEL MAR
# 7                Benicasim                       TAURO
# 8                Benicasim                      AZAHAR
# 9                Benicasim                GRAN AVENIDA
# 10               Benicasim                     FLORIDA
# 11               Benicasim                    BONTERRA
# 12                 Cabanes                   RIBERAMAR
# 13                 Cabanes  CAMPING TORRE LA SAL MARIA
# 14                 Cabanes                  BRAVOPLAYA
# 15                 Cabanes        CAMPING TORRE LA SAL
# 16                   Càlig        CAMPING L'ORANGERAIE
# 17                 Moncofa              CAMPING MONMAR
# 18                 Moncofa                LOS NARANJOS
# 19                 Navajas                    ALTOMIRA
# 20                   Nules            COSTA DE LEVANTE
# 21         Oropesa del Mar                        KIVU
# 22         Oropesa del Mar                      DIDOTA
# 23         Oropesa del Mar                     VORAMAR
# 24         Oropesa del Mar                       OASIS
# 25               Peñíscola                      EL CID
# 26               Peñíscola                     EL EDEN
# 27               Peñíscola                      VIZMAR
# 28               Peñíscola                   LOS PINOS
# 29               Peñíscola                      FERRER
# 30               Peñíscola                    SOL D'OR
# 31               Peñíscola           SPA NATURA RESORT
# 32               Peñíscola                    LA VOLTA
# 33  Pobla de Benifassà, la      LA TINENCA-MOLI L'ABAD
# 34               San Jorge               MAESTRAT PARK
# 35                 Segorbe              MONTE SAN BLAS
# 36                   Tírig            ZIELO DE LEVANTE
# 37             Torreblanca                 TORRENOSTRA
# 38     Villafranca del Cid                      LLOSAR
# 39                 Vinaròs                 CALA PUNTAL
# 40                 Vinaròs                     VINAROS
# 41                   Viver              VILLA DE VIVER
# 42                chilches                MEDITERRANEO
#
#                                             type
# 0   http://krono.act.uji.es/schemas/slodbi#hotel
# 1   http://krono.act.uji.es/schemas/slodbi#hotel
# 2   http://krono.act.uji.es/schemas/slodbi#hotel
# 3   http://krono.act.uji.es/schemas/slodbi#hotel
# 4   http://krono.act.uji.es/schemas/slodbi#hotel
# 5   http://krono.act.uji.es/schemas/slodbi#hotel
# 6   http://krono.act.uji.es/schemas/slodbi#hotel
# 7   http://krono.act.uji.es/schemas/slodbi#hotel
# 8   http://krono.act.uji.es/schemas/slodbi#hotel
# 9   http://krono.act.uji.es/schemas/slodbi#hotel
# 10  http://krono.act.uji.es/schemas/slodbi#hotel
# 11  http://krono.act.uji.es/schemas/slodbi#hotel
# 12  http://krono.act.uji.es/schemas/slodbi#hotel
# 13  http://krono.act.uji.es/schemas/slodbi#hotel
# 14  http://krono.act.uji.es/schemas/slodbi#hotel
# 15  http://krono.act.uji.es/schemas/slodbi#hotel
# 16  http://krono.act.uji.es/schemas/slodbi#hotel
# 17  http://krono.act.uji.es/schemas/slodbi#hotel
# 18  http://krono.act.uji.es/schemas/slodbi#hotel
# 19  http://krono.act.uji.es/schemas/slodbi#hotel
# 20  http://krono.act.uji.es/schemas/slodbi#hotel
# 21  http://krono.act.uji.es/schemas/slodbi#hotel
# 22  http://krono.act.uji.es/schemas/slodbi#hotel
# 23  http://krono.act.uji.es/schemas/slodbi#hotel
# 24  http://krono.act.uji.es/schemas/slodbi#hotel
# 25  http://krono.act.uji.es/schemas/slodbi#hotel
# 26  http://krono.act.uji.es/schemas/slodbi#hotel
# 27  http://krono.act.uji.es/schemas/slodbi#hotel
# 28  http://krono.act.uji.es/schemas/slodbi#hotel
# 29  http://krono.act.uji.es/schemas/slodbi#hotel
# 30  http://krono.act.uji.es/schemas/slodbi#hotel
# 31  http://krono.act.uji.es/schemas/slodbi#hotel
# 32  http://krono.act.uji.es/schemas/slodbi#hotel
# 33  http://krono.act.uji.es/schemas/slodbi#hotel
# 34  http://krono.act.uji.es/schemas/slodbi#hotel
# 35  http://krono.act.uji.es/schemas/slodbi#hotel
# 36  http://krono.act.uji.es/schemas/slodbi#hotel
# 37  http://krono.act.uji.es/schemas/slodbi#hotel
# 38  http://krono.act.uji.es/schemas/slodbi#hotel
# 39  http://krono.act.uji.es/schemas/slodbi#hotel
# 40  http://krono.act.uji.es/schemas/slodbi#hotel
# 41  http://krono.act.uji.es/schemas/slodbi#hotel
# 42  http://krono.act.uji.es/schemas/slodbi#hotel

# %%
#à modifier pour chaque requete, je ne pense pas qu'on puisse automatiser
edges=[(0,1),(1,2)]

# %%
from pyvis.network import Network
import random

net = Network("800px","800px",notebook=True)

couleur = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)]) for i in range(len(doow.columns))]

#mass=5  pour changer la longueur dee l'arrete

i=0
for col in doow:
    net.add_nodes(doow[col].unique(),title=doow[col].unique(),label=doow[col].unique(),color=[couleur[i]]*doow[col].nunique())
    i=i+1

# %%
for m in doow.iterrows():
    for (s,o) in edges:
        net.add_edge(m[1][s],m[1][o])

# %%
net.toggle_physics(True)
net.show('mygraph.html')
# Out:
#         <iframe
#             width="800px"
#             height="800px"
#             src="mygraph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # REST API GET

# %% [markdown]
# fonctions get de base, recup les views du rep actif, ou la config d'une view en particulier

# %%
sparql = SPARQLWrapper(
    "http://LAPTOP-CS19OKIS:7200/repositories/tach1"
)
sparql.setReturnFormat(JSON)


liens=["http://localhost:7200/rest/repositories","http://localhost:7200/rest/sql-views/tables"]
lien=liens[1]
print(lien)
# Out:
# http://localhost:7200/rest/sql-views/tables

# %%
import requests

x = requests.get(lien)
print(x.content)
# Out:
# b'["Activity","ActivityLocation","CityActivity","ComarcaActivities","Hotels","LINKS","Label","ProvinceLocation"]'

# %%
import urllib.request

contents = urllib.request.urlopen(lien).read()

contents
# Out:
# b'["Activity","ActivityLocation","CityActivity","ComarcaActivities","Hotels","LINKS","Label","ProvinceLocation"]'

# %%
import urllib3
http = urllib3.PoolManager()
r = http.request('GET', lien)
r.data
# Out:
# b'["Activity","ActivityLocation","CityActivity","ComarcaActivities","Hotels","LINKS","Label","ProvinceLocation"]'

# %%
"""
import urllib.request
# Create an OpenerDirector with support for Basic HTTP Authentication...
auth_handler = urllib.request.HTTPBasicAuthHandler()
auth_handler.add_password(realm='PDQ Application',
                          uri='https://mahler:8092/site-updates.py',
                          user='klem',
                          passwd='kadidd!ehopper')
opener = urllib.request.build_opener(auth_handler)
# ...and install it globally so it can be used with urlopen.
urllib.request.install_opener(opener)
urllib.request.urlopen('http://www.example.com/login.html')
"""
liens
# Out:
# ['http://localhost:7200/rest/repositories',
#  'http://localhost:7200/rest/sql-views/tables']

# %% [markdown]
# # REST API PUT

# %%
viewrqst="SELECT ?s WHERE {?s ?p ?m1. ?m1 ?pp ?s2.  #!filter}"
#if it can be of any help, I thinkcolumn 50 refers to the closing braces,
#adding a space after filter changes it to column 51

viewbody={
"name": "viewpython",
"query": viewrqst,
"columns":[
{
"column_name":"s",
"column_type":"string",
"nullable":True,
"sparql_type":"string",
"sql_type_precision":0,
"sql_type_scale":0
}]}

print("body i sent : \n")
print(viewbody)
r = requests.post('http://localhost:7200/rest/sql-views/tables/',json=viewbody)

print("\n response i get : \n")
print(r.text)
# Out:
# body i sent :
#
# {'name': 'viewpython', 'query': 'SELECT ?s WHERE {?s ?p ?m1. ?m1 ?pp ?s2.  #!filter}', 'columns': [{'column_name': 's', 'column_type': 'string', 'nullable': True, 'sparql_type': 'string', 'sql_type_precision': 0, 'sql_type_scale': 0}]}
#
#  response i get :
#
# {"message":"Syntax error in query:  (Encountered \"<EOF>\" at line 2, column 51.\r\nWas expecting one of:\r\n    \"{\" ...\r\n    \"}\" ...\r\n    \"optional\" ...\r\n    \"graph\" ...\r\n    \"minus\" ...\r\n    \"filter\" ...\r\n    \"bind\" ...\r\n    \"service\" ...\r\n    \"values\" ...\r\n    )."}

# %%
"PREFIX slodbi: <http://krono.act.uji.es/schemas/slodbi#>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
PREFIX vcard:<http://www.w3.org/2006/vcard/ns#>
PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    
SELECT ?s1 ?s3 ?type
WHERE{
   # ?o rdfs:label ?s1.
   # ?o slodbi:tiene-campings ?s2.
   # ?s2 vcard:fn ?s3.
   # ?s2 rdf:type ?type.
}"

# %%
import urllib.parse
query = 'SELECT ?p { ?o ?p ?s. #!filter }'
urllib.parse.quote(query)
# Out:
# 'SELECT%20%3Fp%20%7B%20%3Fo%20%3Fp%20%3Fs.%20%23%21filter%20%7D'
